# %%
# Set up the credentials in the environment to run the chat bot - Windows (PowerShell)
# setx AWS_ACCESS_KEY_ID YOUR_ACCESS_KEY_ID 
# setx AWS_SECRET_ACCESS_KEY YOUR_SECRET_ACCESS_KEY 
# setx AWS_DEFAULT_REGION us-east-1

# %%
# pip install -U "langchain-core"
# pip install -qU langchain-aws
# pip install langchain langchain-text-splitters langchain-community bs4

# %%
from langchain.tools import tool, ToolRuntime
from langchain_aws import ChatBedrock
from langchain.agents import create_agent
from elasticsearch import Elasticsearch
from langgraph.checkpoint.memory import InMemorySaver  
from langchain.agents.middleware import SummarizationMiddleware
from langchain_core.runnables import RunnableConfig
import json

# %%
from langchain_aws import ChatBedrock

model = ChatBedrock(model="us.anthropic.claude-sonnet-4-5-20250929-v1:0")

# %%
from langchain_aws import BedrockEmbeddings

embeddings = BedrockEmbeddings(model_id="amazon.titan-embed-text-v2:0")

# %%
from langchain_core.vectorstores import InMemoryVectorStore

vector_store = InMemoryVectorStore(embeddings)

# %%
import bs4
from langchain_community.document_loaders import WebBaseLoader

# Only keep post title, headers, and content from the full HTML.
bs4_strainer = bs4.SoupStrainer(class_=("post-title", "post-header", "post-content"))
loader = WebBaseLoader(
    web_paths=("https://lilianweng.github.io/posts/2023-06-23-agent/",),
    bs_kwargs={"parse_only": bs4_strainer},
)
docs = loader.load()

assert len(docs) == 1
print(f"Total characters: {len(docs[0].page_content)}")
# Out:
# Total characters: 43047

# %%
print(docs[0].page_content[:500])
# Out:
#       LLM Powered Autonomous Agents
#
# Date: June 23, 2023  |  Estimated Reading Time: 31 min  |  Author: Lilian Weng
#
#
# Building agents with LLM (large language model) as its core controller is a cool concept. Several proof-of-concepts demos, such as AutoGPT, GPT-Engineer and BabyAGI, serve as inspiring examples. The potentiality of LLM extends beyond generating well-written copies, stories, essays and programs; it can be framed as a powerful general problem solver.
# Agent System Overview#
# In

# %%
from langchain_text_splitters import RecursiveCharacterTextSplitter

text_splitter = RecursiveCharacterTextSplitter(
    chunk_size=1000,  # chunk size (characters)
    chunk_overlap=200,  # chunk overlap (characters)
    add_start_index=True,  # track index in original document
)
all_splits = text_splitter.split_documents(docs)

print(f"Split blog post into {len(all_splits)} sub-documents.")
# Out:
# Split blog post into 63 sub-documents.

# %%
from langchain.tools import tool

@tool(response_format="content_and_artifact")
def retrieve_context(query: str):
    """Retrieve information to help answer a query."""
    retrieved_docs = vector_store.similarity_search(query, k=2)
    serialized = "\n\n".join(
        (f"Source: {doc.metadata}\nContent: {doc.page_content}")
        for doc in retrieved_docs
    )
    return serialized, retrieved_docs

# %%
document_ids = vector_store.add_documents(documents=all_splits)

print(document_ids[:3])
# Out:
# ['bf3eb605-70ad-47f8-a4c3-d12be2fc14ff', '8f35abba-f1bc-49e7-b386-ce4bef9845c9', '274d0396-a830-4428-a505-2267690135ae']

# %%
from langchain.agents import create_agent


tools = [retrieve_context]
# If desired, specify custom instructions
prompt = (
    "You have access to a tool that retrieves context from a blog post. "
    "Use the tool to help answer user queries."
)
agent = create_agent(model, tools, system_prompt=prompt)

# %%
query = (
    "What is the standard method for Task Decomposition?\n\n"
    "Once you get the answer, look up common extensions of that method."
)

for event in agent.stream(
    {"messages": [{"role": "user", "content": query}]},
    stream_mode="values",
):
    event["messages"][-1].pretty_print()
# Out:
# ================================ Human Message =================================
#
# What is the standard method for Task Decomposition?
#
# Once you get the answer, look up common extensions of that method.
# ================================== Ai Message ==================================
#
# Certainly! I'll retrieve the information about the standard method for Task Decomposition and then look up common extensions of that method. Let me use the retrieval tool to get this information for you.
# Tool Calls:
#   retrieve_context (toolu_bdrk_01RQZ3bJbTsACcAcDLVgP6BJ)
#  Call ID: toolu_bdrk_01RQZ3bJbTsACcAcDLVgP6BJ
#   Args:
#     query: What is the standard method for Task Decomposition? What are common extensions of that method?
# ================================= Tool Message =================================
# Name: retrieve_context
#
# Source: {'source': 'https://lilianweng.github.io/posts/2023-06-23-agent/', 'start_index': 2578}
# Content: Task decomposition can be done (1) by LLM with simple prompting like "Steps for XYZ.\n1.", "What are the subgoals for achieving XYZ?", (2) by using task-specific instructions; e.g. "Write a story outline." for writing a novel, or (3) with human inputs.
# Another quite distinct approach, LLM+P (Liu et al. 2023), involves relying on an external classical planner to do long-horizon planning. This approach utilizes the Planning Domain Definition Language (PDDL) as an intermediate interface to describe the planning problem. In this process, LLM (1) translates the problem into “Problem PDDL”, then (2) requests a classical planner to generate a PDDL plan based on an existing “Domain PDDL”, and finally (3) translates the PDDL plan back into natural language. Essentially, the planning step is outsourced to an external tool, assuming the availability of domain-specific PDDL and a suitable planner which is common in certain robotic setups but not in many other domains.
# Self-Reflection#
#
# Source: {'source': 'https://lilianweng.github.io/posts/2023-06-23-agent/', 'start_index': 1638}
# Content: Component One: Planning#
# A complicated task usually involves many steps. An agent needs to know what they are and plan ahead.
# Task Decomposition#
# Chain of thought (CoT; Wei et al. 2022) has become a standard prompting technique for enhancing model performance on complex tasks. The model is instructed to “think step by step” to utilize more test-time computation to decompose hard tasks into smaller and simpler steps. CoT transforms big tasks into multiple manageable tasks and shed lights into an interpretation of the model’s thinking process.
# Tree of Thoughts (Yao et al. 2023) extends CoT by exploring multiple reasoning possibilities at each step. It first decomposes the problem into multiple thought steps and generates multiple thoughts per step, creating a tree structure. The search process can be BFS (breadth-first search) or DFS (depth-first search) with each state evaluated by a classifier (via a prompt) or majority vote.
# ================================== Ai Message ==================================
#
# Based on the retrieved information, I can answer your questions about the standard method for Task Decomposition and its common extensions.
#
# The standard method for Task Decomposition:
# The standard method for Task Decomposition is Chain of Thought (CoT), introduced by Wei et al. in 2022. This method involves instructing the model to "think step by step" to break down complex tasks into smaller, more manageable steps. It's a prompting technique that enhances model performance on complicated tasks by utilizing more test-time computation.
#
# Common extensions of the Chain of Thought method:
#
# 1. Tree of Thoughts (ToT):
#    This is an extension of CoT proposed by Yao et al. in 2023. Instead of following a linear chain of reasoning, ToT explores multiple reasoning possibilities at each step. It creates a tree structure by:
#    - Decomposing the problem into multiple thought steps
#    - Generating multiple thoughts per step
#    - Using either Breadth-First Search (BFS) or Depth-First Search (DFS) to explore the tree
#    - Evaluating each state using a classifier (via a prompt) or majority vote
#
# 2. LLM+P (Liu et al. 2023):
#    This approach combines Large Language Models with classical planners for long-horizon planning. It uses the Planning Domain Definition Language (PDDL) as an intermediate interface. The process involves:
#    - LLM translating the problem into "Problem PDDL"
#    - Requesting a classical planner to generate a PDDL plan based on an existing "Domain PDDL"
#    - LLM translating the PDDL plan back into natural language
#
# 3. Task-specific instructions:
#    This method involves using domain-specific prompts for task decomposition. For example, when writing a novel, the prompt might be "Write a story outline."
#
# 4. Human-in-the-loop decomposition:
#    This approach incorporates human inputs to guide the task decomposition process.
#
# 5. Simple prompting techniques:
#    These include using prompts like "Steps for XYZ.\n1." or "What are the subgoals for achieving XYZ?" to encourage the model to break down tasks.
#
# These extensions and variations on the standard Chain of Thought method offer different approaches to task decomposition, catering to various complexities and domain-specific requirements. The choice of method often depends on the specific task, available resources, and desired level of detail in the planning process.

# %%
from elasticsearch import Elasticsearch

# %%
es = Elasticsearch(
        hosts=['https://sqml-dhmp.es.us-west-2.aws.found.io:9243'],
        basic_auth=('elastic', 'f7VU4FcOvsnrYr4poj9H4LG0')
    )
# Test the connection by getting cluster info
info = es.info()
print("Connected to Elasticsearch!")
print(f"Cluster name: {info['cluster_name']}")
# Out:
# Connected to Elasticsearch!
# Cluster name: 19c8ca233239405e8c2ec66b872b1e05

# %%
index_info = es.indices.get(index='tiamd_prod_clinical_notes')
print(f"\nInformation for index '{index_info}':")
# Out:
# Information for index '{'tiamd_prod_clinical_notes': {'aliases': {}, 'mappings': {'properties': {'dateOfService': {'type': 'date', 'format': 'MM-DD-YYYY'}, 'dateOfServiceEpoch': {'type': 'long'}, 'ingestionDate': {'type': 'date', 'format': 'epoch_millis'}, 'ingestionDateTime': {'type': 'text', 'fields': {'keyword': {'type': 'keyword', 'ignore_above': 256}}}, 'ingestionTS': {'type': 'long'}, 'location': {'type': 'keyword'}, 'locationname': {'type': 'keyword'}, 'mrn': {'type': 'keyword'}, 'noteId': {'type': 'keyword'}, 'noteType': {'type': 'keyword'}, 'pateintName': {'type': 'keyword'}, 'pateintname': {'type': 'text', 'fields': {'keyword': {'type': 'keyword', 'ignore_above': 256}}}, 'patientID': {'type': 'text', 'fields': {'keyword': {'type': 'keyword', 'ignore_above': 256}}}, 'patientId': {'type': 'keyword'}, 'patientMRN': {'type': 'keyword'}, 'patientName': {'type': 'keyword'}, 'patientname': {'type': 'keyword'}, 'rawdata': {'type': 'keyword'}, 'serviceDate': {'type': 'text', 'fields': {'keyword': {'type': 'keyword', 'ignore_above': 256}}}, 'status': {'type': 'keyword'}}}, 'settings': {'index': {'routing': {'allocation': {'include': {'_tier_preference': 'data_content'}}}, 'number_of_shards': '1', 'provided_name': 'tiamd_prod_clinical_notes', 'creation_date': '1763731424961', 'number_of_replicas': '1', 'uuid': '_mk2oSd9ST6qJ8aXTCKrJQ', 'version': {'created': '8060299'}}}}}':

# %%
response = es.get(index='tiamd_prod_clinical_notes', id=98)

# %%
raw_text = response["_source"]["rawdata"]

# %%
print(raw_text)
# Out:
# MRN: Mrn6790 Erin Rajeev, MD Erin Rajeev, MD Physician Neurology Consults The patient can view the shared note after they get an active MyChart account This note has been shared with the patient Signed Date of Service: 11/05/2025 11:58 AM Consult Orders Signed 43912 Wood Ave, Sui 102 field Tkk, IP 4465 Phone #: 124-955-2345 | Fax #: 248-928-9088 Pavithra, MD MPH Tay, MD Rama, MD Isma DO Alen, DO Neurology consult Name: Ann Mathew DOB: 8/23/1955 Age: 70 y.o. Sex: female MRN: Mrn6790 CSN: 1000520864654 Admit date: 11/05/2025 Attending: Erin Rajeev, MD Date of consult:11/05/2025 CCD: Reason for Consult: Subjective HPI 70 y.o. female with a PMH of schizophrenia, CKD presents to the emergency room brought in with her sister for acute mental status change. Sister states yesterday and today patient has refused to eat and drink, has had very little conversation and response at home. Denies any fever chills nausea vomiting or diarrhea. States she was under the weather last week with a cough and has been diaphoretic today. sister providing most of the history as patient has very minimal verbal response. Sister states the patient has always been cognitively delayed and diagnosed schizophrenia years ago. She states the patient was living with her other sister for years but she passed away last year. Since then patient has been progressively declining with mentation and depression. Sister states she brought her to live with her in January because the patient was found wandering the neighborhood in the dark and not getting out of bed and refusing to eat and drink. The sister states this happened last month as well and she was admitted to Beaumont with dehydration. The sister is worried the patient is slowly getting worse with underlying dementia and a psychiatric component. She is not legal DPOA, patient needs social work and guardianship, sister does not feel the patient will be safe at her house. Pt was admitted to hospital for further evaluation. Shes awake in room, knows shes in hospital but not sure why shes here. Review of Systems Fourteen point ROS is negative except for symptoms mentioned in HPI Past Medical History: No date: Schizophrenia (CMS/HCC V24, CMS/HCC V28) No past surgical history on file. Allergy - Patient has no known allergies. Social History Social History Tobacco Use &bull; Smoking status: Never &bull; Smokeless tobacco: Never Substance Use Topics &bull; Alcohol use: Never Family History No family history on file. Prescriptions Prior to Admission Medications Prior to Admission Medication Sig Dispense Refill Last Dose/Taking &bull; aspirin 81 mg chewable tablet Chew 1 tablet (81 mg total) 1 (one) time each day. 11/05/2025 Morning &bull; fluvoxaMINE (LUVOX) 100 mg tablet Take 1 tablet (100 mg total) by mouth at bedtime. 11/05/2025 &bull; QUEtiapine (SEROquel) 100 mg tablet Take 1 tablet (100 mg total) by mouth at bedtime. 11/05/2025 Objective Physical exam Temp -36.9 &deg;C (98.4 &deg;F) BP - 111/50 HR - 76 RR - 16 SpO2 - 93 % NEUROLOGIC: a comprehensive neurologic exam was performed. Higher Functions: Patient is awake, is able to answer slowly. Patient is dysarthric. Memory immediate memory is poor, unable to do three-step commands. Disoriented to time. Able to say that she is in the hospital. Cranial nerves: EYES: Pupils are equal reactive to light. Extraocular movements are full. Cranial nerves appear normal Motor system: Patient is able to move all 4 extremities. Has dyskinetic movements over the face. Has involuntary movements in her right upper extremity more than the left. Sensory system: Sensory exam is normal Reflexes: Present Labs Lab Results Component Value Date WBC 13.1 (H) 11/05/2025 HGB 13.0 11/05/2025 PLT 259 11/05/2025 Lab Results Component Value Date NA 138 11/05/2025 K 3.5 11/05/2025 MG 1.6 (L) 11/05/2025 GLUCOSE 88 10/05/2025 CALCIUM 9.3 11/05/2025 CREATININE 1.01 11/05/2025 BUN 26 (H) 11/05/2025 Lab Results Component Value Date ALT 23 11/05/2025 AST 29 11/05/2025 No results found for: CHOL, TRIG, HDL ...

# %%
from langchain_core.documents import Document

# Put size inside the body parameter
response = es.search(
    index='tiamd_prod_clinical_notes', 
    body={
        "query": {"match_all": {}},
        "size": 100
    }
)

docs = []
for hit in response['hits']['hits']:
    doc = Document(
        page_content=hit["_source"]["rawdata"],
        metadata={
            "id": hit["_id"],
            "index": hit["_index"],
            "noteId": hit["_source"].get("noteId"),
            "patientName": hit["_source"].get("patientName"),
            "dateOfService": hit["_source"].get("dateOfService"),
        }
    )
    docs.append(doc)

# %%
docs[0:5]
# Out:
# %%
from langchain_core.vectorstores import InMemoryVectorStore

vector_store = InMemoryVectorStore(embeddings)

document_ids = vector_store.add_documents(documents=all_splits)

print(document_ids[:3])
# Out:
# ['c94c936a-26f7-4ede-aea3-2bfb26c716c0', '11beb047-dc60-4406-9ef3-5e96490bb903', 'd447bb77-32ea-45f8-8293-58e00fb6e04e']

# %%
from langchain.tools import tool

@tool(response_format="content_and_artifact")
def retrieve_context(query: str):
    """Retrieve information to help answer a query."""
    retrieved_docs = vector_store.similarity_search(query, k=7)
    serialized = "\n\n".join(
        (f"Source: {doc.metadata}\nContent: {doc.page_content}")
        for doc in retrieved_docs
    )
    return serialized, retrieved_docs

@tool(description="Retrieve the mappings for a specified Elasticsearch index")
def get_index_mappings(index: str, runtime: ToolRuntime = None) -> dict:
    mappings = es.indices.get_mapping(index=index)
    return mappings

@tool(description="Execute an Elasticsearch DSL query and return the results")
def run_es_query(index: str, dsl_query: str, runtime: ToolRuntime = None) -> dict:
    query_dict = json.loads(dsl_query)

    # Replace 'body' with individual parameters
    query_params = {}
    if "query" in query_dict:
        query_params["query"] = query_dict["query"]
    if "aggs" in query_dict:
        query_params["aggs"] = query_dict["aggs"]
    if "size" in query_dict:
        query_params["size"] = query_dict["size"]

    response = es.search(index=index, **query_params)
    return {"dsl": query_dict, "results": response}

# %%
from langchain.agents import create_agent


tools = [retrieve_context, get_index_mappings, run_es_query]
# If desired, specify custom instructions
prompt = (
    """ 
You are a clinical data assistant.

You have THREE tools:

1. retrieve_context
   - Use this ONLY to understand, summarize, or explain clinical notes
   - Example: patient history, consultation summary, medications

2. get_index_mappings
   - Use this BEFORE writing any Elasticsearch query

3. run_es_query
   - Use this ONLY for counts, filters, or aggregations

---------------------------------
## TOOL SELECTION RULES

If the question is about a specific patient or clinical text
  - Use retrieve_context
  - Do NOT use Elasticsearch aggregations

If the question asks for numbers, counts, totals, or statistics
  - Do NOT use retrieve_context
  - First call get_index_mappings
  - Then call run_es_query

---------------------------------
## ELASTICSEARCH RULES

• Query ONLY this index: tiamd_prod_processed_notes_json
• Use cardinality for "how many" or "unique"
• Use keyword fields for aggregations
• Use size = 0 for aggregation-only queries
• Do NOT guess field names

---------------------------------
Choose the correct tool. Using the wrong tool is an error.


"""
)
agent = create_agent(model, tools, system_prompt=prompt, checkpointer=InMemorySaver())

# %%
result = agent.invoke(
    {"messages": [{"role": "user", "content": "Number of patients under doctor madhavan?"}]},
    {"configurable": {"thread_id": "1"}}
)

# %%
print(result['messages'][-1].content)
# Out:
# **Number of patients under Dr. Madhavan: 10**
#
# This is based on finding 27 clinical notes where Dr. Madhavan appears as an attending physician, consulting specialist, or note author, representing 10 unique patients (identified by unique MRNs).

# %%
result = agent.invoke(
    {"messages": [{"role": "user", "content": "List the patients in the data"}]},
    {"configurable": {"thread_id": "1"}}
)

# %%
print(result['messages'][-1].content)
# Out:
# ## **All Patients in the Dataset (12 unique patients):**
#
# 1. **Frank P Barazsu**
#    - MRN: 101972538
#    - Age: 74 years
#    - Sex: Male
#    - Number of Notes: 4
#
# 2. **Debra Garrison**
#    - MRN: 101548585
#    - Age: 70 years
#    - Sex: Female
#    - Number of Notes: 3
#
# 3. **Michele Hedy Schlaud**
#    - MRN: 101587502
#    - Age: 74 years
#    - Sex: Female
#    - Number of Notes: 3
#
# 4. **Wilma Nicholson**
#    - MRN: 101697051
#    - Age: 88 years
#    - Sex: Female
#    - Number of Notes: 3
#
# 5. **William C Robinson**
#    - MRN: 101793660
#    - Age: 65 years
#    - Sex: Male
#    - Number of Notes: 3
#
# 6. **Darleen M Sutherland**
#    - MRN: 101891023
#    - Age: 87 years
#    - Sex: Female
#    - Number of Notes: 3
#
# 7. **Judith Masterson**
#    - MRN: 102025939
#    - Age: 66 years
#    - Sex: Female
#    - Number of Notes: 3
#
# 8. **Marvin D Silver**
#    - MRN: 20319274
#    - Age: 88 years
#    - Sex: Male
#    - Number of Notes: 3
#
# 9. **Doris L Pippen**
#    - MRN: 101700652
#    - Age: 79 years
#    - Sex: Female
#    - Number of Notes: 2
#
# 10. **Evelyn McHaney**
#     - MRN: 101798833
#     - Age: 92 years
#     - Sex: Female
#     - Number of Notes: 2
#
# 11. **William B Kupp**
#     - MRN: 101803777
#     - Age: 92 years
#     - Sex: Male
#     - Number of Notes: 2
#
# 12. **Ann Mathew**
#     - MRN: Mrn6790
#     - Age: 70 years
#     - Sex: Female
#     - Number of Notes: 1
#
# ---
#
# **Summary:**
# - **Total Patients:** 12
# - **Total Clinical Notes:** 33
# - **Gender Distribution:** 8 Female, 4 Male
# - **Age Range:** 65-92 years

# %%
result = agent.invoke(
    {"messages": [{"role": "user", "content": "What are the medications for the patient Doris L Pippen"}]},
    {"configurable": {"thread_id": "1"}}
)

# %%
print(result['messages'][-1].content)
# Out:
# Based on the clinical notes for **Doris L Pippen** (MRN: 101700652, DOB: 12/3/1945), here are her medications:
#
# ## **Medications Prior to Admission:**
# - **amLODIPine (NORVASC)** 2.5 mg tablet - once daily
# - **losartan-hydroCHLOROthiazide (HYZAAR)** 100-12.5 mg tablet - once daily
# - **rosuvastatin (CRESTOR)** 20 mg tablet - once daily
#
# ## **Current Outpatient Medications** (from another note):
# - **amLODIPine (NORVASC)** 5 mg tablet
# - **atorvastatin (LIPITOR)** 40 mg tablet - once daily for hypercholesterolemia
# - **clopidogrel (PLAVIX)** 75 mg tablet - once daily
# - **cyanocobalamin** 1,000 mcg tablet (Vitamin B-12)
# - **donepezil (ARICEPT)** 10 mg tablet - nightly
# - **ipratropium (ATROVENT)** 0.06% nasal spray - 2 sprays twice daily
# - **latanoprost (XALATAN)** 0.005% ophthalmic solution
# - **loratadine (CLARITIN)** 10 mg tablet - as needed
# - **losartan (COZAAR)** 100 mg tablet - once daily for hypertension
# - **pantoprazole (PROTONIX)** 40 mg
#
# The medication records show some variations between different time points, which is common as medications are adjusted during hospital admissions and follow-up care.

# %%
result = agent.invoke(
    {"messages": [{"role": "user", "content": "What was my last questions"}]},
    {"configurable": {"thread_id": "1"}}
)

# %%
result
# Out:
# {'messages': [HumanMessage(content='Number of patients in this dataset?', additional_kwargs={}, response_metadata={}, id='4c15a4d2-e292-4864-baac-2395a8a01aa9'),
#   AIMessage(content="I need to find the number of unique patients in the dataset. This is a count/aggregation question, so I'll first get the index mappings to identify the correct field for patient identification, then run an Elasticsearch query.", additional_kwargs={'usage': {'prompt_tokens': 1315, 'completion_tokens': 112, 'cache_read_input_tokens': 0, 'cache_write_input_tokens': 0, 'total_tokens': 1427}, 'stop_reason': 'tool_use', 'thinking': {}, 'model_id': 'us.anthropic.claude-sonnet-4-5-20250929-v1:0', 'model_name': 'us.anthropic.claude-sonnet-4-5-20250929-v1:0'}, response_metadata={'usage': {'prompt_tokens': 1315, 'completion_tokens': 112, 'cache_read_input_tokens': 0, 'cache_write_input_tokens': 0, 'total_tokens': 1427}, 'stop_reason': 'tool_use', 'thinking': {}, 'model_id': 'us.anthropic.claude-sonnet-4-5-20250929-v1:0', 'model_name': 'us.anthropic.claude-sonnet-4-5-20250929-v1:0'}, id='lc_run--019b21e1-68a2-75c1-a41b-77666955e197-0', tool_calls=[{'name': 'get_index_mappings', 'args': {'index': 'tiamd_prod_clinical_notes'}, 'id': 'toolu_bdrk_012KHGE3E6Ur2TTLkNEvD8yn', 'type': 'tool_call'}], usage_metadata={'input_tokens': 1315, 'output_tokens': 112, 'total_tokens': 1427, 'input_token_details': {'cache_creation': 0, 'cache_read': 0}}),
#   ToolMessage(content="{'tiamd_prod_clinical_notes': {'mappings': {'properties': {'dateOfService': {'type': 'date', 'format': 'MM-DD-YYYY'}, 'dateOfServiceEpoch': {'type': 'long'}, 'ingestionDate': {'type': 'date', 'format': 'epoch_millis'}, 'ingestionDateTime': {'type': 'text', 'fields': {'keyword': {'type': 'keyword', 'ignore_above': 256}}}, 'ingestionTS': {'type': 'long'}, 'location': {'type': 'keyword'}, 'locationname': {'type': 'keyword'}, 'mrn': {'type': 'keyword'}, 'noteId': {'type': 'keyword'}, 'noteType': {'type': 'keyword'}, 'pateintName': {'type': 'keyword'}, 'pateintname': {'type': 'text', 'fields': {'keyword': {'type': 'keyword', 'ignore_above': 256}}}, 'patientID': {'type': 'text', 'fields': {'keyword': {'type': 'keyword', 'ignore_above': 256}}}, 'patientId': {'type': 'keyword'}, 'patientMRN': {'type': 'keyword'}, 'patientName': {'type': 'keyword'}, 'patientname': {'type': 'keyword'}, 'rawdata': {'type': 'keyword'}, 'serviceDate': {'type': 'text', 'fields': {'keyword': {'type': 'keyword', 'ignore_above': 256}}}, 'status': {'type': 'keyword'}}}}}", name='get_index_mappings', id='d914c5d4-c7f7-4f42-a05a-dd5fe93e8f85', tool_call_id='toolu_bdrk_012KHGE3E6Ur2TTLkNEvD8yn'),
#   AIMessage(content="Now I'll use the `mrn` field (Medical Record Number) to count unique patients using a cardinality aggregation:", additional_kwargs={'usage': {'prompt_tokens': 1850, 'completion_tokens': 161, 'cache_read_input_tokens': 0, 'cache_write_input_tokens': 0, 'total_tokens': 2011}, 'stop_reason': 'tool_use', 'thinking': {}, 'model_id': 'us.anthropic.claude-sonnet-4-5-20250929-v1:0', 'model_name': 'us.anthropic.claude-sonnet-4-5-20250929-v1:0'}, response_metadata={'usage': {'prompt_tokens': 1850, 'completion_tokens': 161, 'cache_read_input_tokens': 0, 'cache_write_input_tokens': 0, 'total_tokens': 2011}, 'stop_reason': 'tool_use', 'thinking': {}, 'model_id': 'us.anthropic.claude-sonnet-4-5-20250929-v1:0', 'model_name': 'us.anthropic.claude-sonnet-4-5-20250929-v1:0'}, id='lc_run--019b21e1-761c-7f63-8660-26d995cf9922-0', tool_calls=[{'name': 'run_es_query', 'args': {'index': 'tiamd_prod_clinical_notes', 'dsl_query': '{\n  "size": 0,\n  "aggs": {\n    "unique_patients": {\n      "cardinality": {\n        "field": "mrn"\n      }\n    }\n  }\n}'}, 'id': 'toolu_bdrk_01KNzX6CXe8TRDry4hcRyum9', 'type': 'tool_call'}], usage_metadata={'input_tokens': 1850, 'output_tokens': 161, 'total_tokens': 2011, 'input_token_details': {'cache_creation': 0, 'cache_read': 0}}),
#   ToolMessage(content="{'dsl': {'size': 0, 'aggs': {'unique_patients': {'cardinality': {'field': 'mrn'}}}}, 'results': ObjectApiResponse({'took': 2, 'timed_out': False, '_shards': {'total': 1, 'successful': 1, 'skipped': 0, 'failed': 0}, 'hits': {'total': {'value': 27, 'relation': 'eq'}, 'max_score': None, 'hits': []}, 'aggregations': {'unique_patients': {'value': 0}}})}", name='run_es_query', id='8b630594-bf99-4b06-a26a-06c4bb5fff57', tool_call_id='toolu_bdrk_01KNzX6CXe8TRDry4hcRyum9'),
#   AIMessage(content='The cardinality aggregation on the `mrn` field returned 0, which suggests the `mrn` field might be empty. Let me try using the `patientId` field instead:', additional_kwargs={'usage': {'prompt_tokens': 2165, 'completion_tokens': 177, 'cache_read_input_tokens': 0, 'cache_write_input_tokens': 0, 'total_tokens': 2342}, 'stop_reason': 'tool_use', 'thinking': {}, 'model_id': 'us.anthropic.claude-sonnet-4-5-20250929-v1:0', 'model_name': 'us.anthropic.claude-sonnet-4-5-20250929-v1:0'}, response_metadata={'usage': {'prompt_tokens': 2165, 'completion_tokens': 177, 'cache_read_input_tokens': 0, 'cache_write_input_tokens': 0, 'total_tokens': 2342}, 'stop_reason': 'tool_use', 'thinking': {}, 'model_id': 'us.anthropic.claude-sonnet-4-5-20250929-v1:0', 'model_name': 'us.anthropic.claude-sonnet-4-5-20250929-v1:0'}, id='lc_run--019b21e1-fcd4-77c1-b299-2aba0b01787b-0', tool_calls=[{'name': 'run_es_query', 'args': {'index': 'tiamd_prod_clinical_notes', 'dsl_query': '{\n  "size": 0,\n  "aggs": {\n    "unique_patients": {\n      "cardinality": {\n        "field": "patientId"\n      }\n    }\n  }\n}'}, 'id': 'toolu_bdrk_012gcxcZcRLYJ5js8r5rVyHY', 'type': 'tool_call'}], usage_metadata={'input_tokens': 2165, 'output_tokens': 177, 'total_tokens': 2342, 'input_token_details': {'cache_creation': 0, 'cache_read': 0}}),
#   ToolMessage(content="{'dsl': {'size': 0, 'aggs': {'unique_patients': {'cardinality': {'field': 'patientId'}}}}, 'results': ObjectApiResponse({'took': 110, 'timed_out': False, '_shards': {'total': 1, 'successful': 1, 'skipped': 0, 'failed': 0}, 'hits': {'total': {'value': 27, 'relation': 'eq'}, 'max_score': None, 'hits': []}, 'aggregations': {'unique_patients': {'value': 0}}})}", name='run_es_query', id='b9e3192f-9ea5-4360-bf02-30dc3a9c905e', tool_call_id='toolu_bdrk_012gcxcZcRLYJ5js8r5rVyHY'),
#   AIMessage(content='Still getting 0. Let me try `patientMRN`:', additional_kwargs={'usage': {'prompt_tokens': 2497, 'completion_tokens': 152, 'cache_read_input_tokens': 0, 'cache_write_input_tokens': 0, 'total_tokens': 2649}, 'stop_reason': 'tool_use', 'thinking': {}, 'model_id': 'us.anthropic.claude-sonnet-4-5-20250929-v1:0', 'model_name': 'us.anthropic.claude-sonnet-4-5-20250929-v1:0'}, response_metadata={'usage': {'prompt_tokens': 2497, 'completion_tokens': 152, 'cache_read_input_tokens': 0, 'cache_write_input_tokens': 0, 'total_tokens': 2649}, 'stop_reason': 'tool_use', 'thinking': {}, 'model_id': 'us.anthropic.claude-sonnet-4-5-20250929-v1:0', 'model_name': 'us.anthropic.claude-sonnet-4-5-20250929-v1:0'}, id='lc_run--019b21e2-0c2f-7452-9939-a2abee776202-0', tool_calls=[{'name': 'run_es_query', 'args': {'index': 'tiamd_prod_clinical_notes', 'dsl_query': '{\n  "size": 0,\n  "aggs": {\n    "unique_patients": {\n      "cardinality": {\n        "field": "patientMRN"\n      }\n    }\n  }\n}'}, 'id': 'toolu_bdrk_011Xb6wXc2QSEfD8cqhGQCqq', 'type': 'tool_call'}], usage_metadata={'input_tokens': 2497, 'output_tokens': 152, 'total_tokens': 2649, 'input_token_details': {'cache_creation': 0, 'cache_read': 0}}),
#   ToolMessage(content="{'dsl': {'size': 0, 'aggs': {'unique_patients': {'cardinality': {'field': 'patientMRN'}}}}, 'results': ObjectApiResponse({'took': 6, 'timed_out': False, '_shards': {'total': 1, 'successful': 1, 'skipped': 0, 'failed': 0}, 'hits': {'total': {'value': 27, 'relation': 'eq'}, 'max_score': None, 'hits': []}, 'aggregations': {'unique_patients': {'value': 17}}})}", name='run_es_query', id='f14179d6-686c-4013-af4f-e06c44b12ce7', tool_call_id='toolu_bdrk_011Xb6wXc2QSEfD8cqhGQCqq'),
#   AIMessage(content='Perfect! Based on the cardinality aggregation on the `patientMRN` field:\n\n**There are 17 unique patients in this dataset.**\n\nThe dataset contains a total of 27 clinical notes across these 17 patients.', additional_kwargs={'usage': {'prompt_tokens': 2806, 'completion_tokens': 56, 'cache_read_input_tokens': 0, 'cache_write_input_tokens': 0, 'total_tokens': 2862}, 'stop_reason': 'end_turn', 'thinking': {}, 'model_id': 'us.anthropic.claude-sonnet-4-5-20250929-v1:0', 'model_name': 'us.anthropic.claude-sonnet-4-5-20250929-v1:0'}, response_metadata={'usage': {'prompt_tokens': 2806, 'completion_tokens': 56, 'cache_read_input_tokens': 0, 'cache_write_input_tokens': 0, 'total_tokens': 2862}, 'stop_reason': 'end_turn', 'thinking': {}, 'model_id': 'us.anthropic.claude-sonnet-4-5-20250929-v1:0', 'model_name': 'us.anthropic.claude-sonnet-4-5-20250929-v1:0'}, id='lc_run--019b21e2-1b90-73a3-9aa7-bbb7877f8c64-0', usage_metadata={'input_tokens': 2806, 'output_tokens': 56, 'total_tokens': 2862, 'input_token_details': {'cache_creation': 0, 'cache_read': 0}}),
#   HumanMessage(content='What was my last questions', additional_kwargs={}, response_metadata={}, id='9d75e38f-7628-4000-8d27-f192e37533f3'),
#   AIMessage(content='Your last question was: **"Number of patients in this dataset?"**\n\nI answered that there are 17 unique patients in the dataset, based on the `patientMRN` field in the clinical notes index.', additional_kwargs={'usage': {'prompt_tokens': 2870, 'completion_tokens': 50, 'cache_read_input_tokens': 0, 'cache_write_input_tokens': 0, 'total_tokens': 2920}, 'stop_reason': 'end_turn', 'thinking': {}, 'model_id': 'us.anthropic.claude-sonnet-4-5-20250929-v1:0', 'model_name': 'us.anthropic.claude-sonnet-4-5-20250929-v1:0'}, response_metadata={'usage': {'prompt_tokens': 2870, 'completion_tokens': 50, 'cache_read_input_tokens': 0, 'cache_write_input_tokens': 0, 'total_tokens': 2920}, 'stop_reason': 'end_turn', 'thinking': {}, 'model_id': 'us.anthropic.claude-sonnet-4-5-20250929-v1:0', 'model_name': 'us.anthropic.claude-sonnet-4-5-20250929-v1:0'}, id='lc_run--019b21e4-27e4-70d0-a6d1-5472229d5566-0', usage_metadata={'input_tokens': 2870, 'output_tokens': 50, 'total_tokens': 2920, 'input_token_details': {'cache_creation': 0, 'cache_read': 0}})]}

# %%
query = "What information is available in these clinical notes?"

for event in agent.stream(
    {"messages": [{"role": "user", "content": query}]},
    stream_mode="values",
):
    event["messages"][-1].pretty_print()
# Out:
# ================================ Human Message =================================
#
# What information is available in these clinical notes?
# ================================== Ai Message ==================================
#
# To answer your question about what information is available in the clinical notes, I'll need to use the retrieval tool to get an overview of the content. Let me do that for you.
# Tool Calls:
#   retrieve_context (toolu_bdrk_012A9VHjuWkFZgeTF95bNUZn)
#  Call ID: toolu_bdrk_012A9VHjuWkFZgeTF95bNUZn
#   Args:
#     query: What information is available in these clinical notes? Give an overview of the content.
# ================================= Tool Message =================================
# Name: retrieve_context
#
# Source: {'id': '104', 'index': 'tiamd_prod_clinical_notes', 'noteId': '104', 'patientName': None, 'dateOfService': None, 'start_index': 3187}
# Content: &nbsp; ALT 16 10/03/2025 &nbsp; AST 34 10/03/2025 &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; Lab Results Component Value Date &nbsp; CHOL 189 10/05/2025 &nbsp; TRIG 61 10/05/2025 &nbsp; HDL 57 10/05/2025 &nbsp; LDLCALC 120 10/05/2025 &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; Lab Results Component Value Date &nbsp; VITAMINB12 1,414 (H) 07/08/2025 &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; Lab Results Component Value Date &nbsp; TSH 2.12 10/05/2025 &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; Lab Results Component Value Date &nbsp; HGBA1C 5.8 (H) 10/04/2025 &nbsp; Magnesium 10/3/2025 -1.9 Ammonia 10/4/2025 -49 Lactate 10/3/2025 - 1.2 High sensitivity Trop I 10/4/2025 - 171 Lipid profile 10/5/2025 - Chol 189, HDL 57, TG 61, VLDL 12.2, LDL 120 HbA1c 10/4/2025 - 5.8 TSH 10/5/2025 - 2.12 Free T4 10/4/2025 - 1.55 Quantiferon GOLD 9/23/2021 - positive CMV IgG 9/15/2021 - 6.50 (H) Urinalysis 10/3/2025 - protein trace, blood trace, hyaline casts 11-20 &nbsp; Studies &nbsp; Routine EEG 10/4/2025 - results awaited CTH wo
#
# Source: {'id': '110', 'index': 'tiamd_prod_clinical_notes', 'noteId': '110', 'patientName': None, 'dateOfService': None, 'start_index': 7187}
# Content: &nbsp; Assessment and plan - Mild to moderate cognitive impairment- Dementia - Acute Metabolic Encephalopathy with Visual Hallucinations -Charles Bonnett syndrome - Recurrent Major Depression - Generalized Anxiety - Gastroesophageal Reflux Disease - Tension Headache - Hypertensive Urgency - Possible Urinary Tract Infection - Electrolyte Imbalance with Hyponatremia - Improving - Acute Kidney Injury secondary to Dehydration - Debility and Unsteady Gait with Frequent Falls - Essential Hypertension - Chronic Atrial Fibrillation with Controlled Rate - On Xarelto - History of Invasive Ductal Carcinoma of Right Breast, ER/PR Positive, HER2 Negative. Status Post Right Breast Lumpectomy and Radiation. On Neoadjuvant Anastrozole - Chronic Atypical Chest Discomfort/Burning Sensation. Most likely secondary to History of Radiation Therapy - Dyslipidemia - Valvular Heart Disease with Moderate Aortic Regurgitation, Mild to Moderate Mitral Regurgitation and Mild to Moderate Tricuspid Regurgitation -
# ================================== Ai Message ==================================
#
# Based on the retrieved information, I can provide you with an overview of the content available in these clinical notes. The clinical notes contain a wealth of medical information, including:
#
# 1. Laboratory Results:
#    - Liver function tests (ALT, AST)
#    - Lipid profile (Cholesterol, Triglycerides, HDL, LDL)
#    - Vitamin B12 levels
#    - Thyroid function tests (TSH, Free T4)
#    - Hemoglobin A1c (HbA1c)
#    - Electrolytes (Magnesium)
#    - Ammonia levels
#    - Lactate levels
#    - Cardiac markers (High sensitivity Troponin I)
#    - Quantiferon GOLD test (for tuberculosis)
#    - CMV IgG test
#
# 2. Urinalysis results
#
# 3. Diagnostic Studies:
#    - EEG (Electroencephalogram)
#    - CT scan of the head
#
# 4. Medical Conditions and Diagnoses:
#    - Cognitive impairment and dementia
#    - Acute metabolic encephalopathy with visual hallucinations
#    - Charles Bonnet syndrome
#    - Recurrent major depression
#    - Generalized anxiety
#    - Gastroesophageal reflux disease (GERD)
#    - Tension headache
#    - Hypertensive urgency
#    - Possible urinary tract infection
#    - Electrolyte imbalance (hyponatremia)
#    - Acute kidney injury
#    - Unsteady gait and frequent falls
#    - Essential hypertension
#    - Chronic atrial fibrillation
#    - History of invasive ductal carcinoma of the right breast
#    - Dyslipidemia
#    - Valvular heart disease
#
# 5. Treatments and Medications:
#    - Xarelto (anticoagulant)
#    - Anastrozole (hormone therapy for breast cancer)
#    - History of right breast lumpectomy and radiation therapy
#
# This overview provides a comprehensive picture of the patient's health status, including current medical conditions, past medical history, laboratory results, and ongoing treatments. The notes appear to be from multiple dates, spanning from 2021 to 2025, suggesting that this is a compilation of information from various clinical visits and tests.

# %%
query = "Number of patients in this dataset?"

for event in agent.stream(
    {"messages": [{"role": "user", "content": query}]},
    stream_mode="values",
):
    event["messages"][-1].pretty_print()
# Out:
# ================================ Human Message =================================
#
# Number of patients in this dataset?
# ================================== Ai Message ==================================
#
# To answer your question about the number of patients in the dataset, I'll need to retrieve some context information. Let me use the retrieval tool to get this information for you.
# Tool Calls:
#   retrieve_context (toolu_bdrk_013d63UArvRPTc8vSdgetxQz)
#  Call ID: toolu_bdrk_013d63UArvRPTc8vSdgetxQz
#   Args:
#     query: Number of patients in the dataset
# ================================= Tool Message =================================
# Name: retrieve_context
#
# Source: {'id': '109', 'index': 'tiamd_prod_clinical_notes', 'noteId': '109', 'patientName': None, 'dateOfService': None, 'start_index': 4790}
# Content: ROS is negative except for symptoms mentioned in HPI &nbsp; Past Medical History: No date: Abdominal pain No date: Acid reflux No date: Altered level of consciousness Comment: in past; pt does have short term memory problems per daughter No date: Aneurysm (CMS/HCC V24) No date: Anxiety No date: Arthritis No date: Cerebral aneurysm No date: Colitis No date: Constipation No date: CVA (cerebral vascular accident) (CMS/HCC V24, CMS/HCC V28) No date: Dementia (CMS/HCC V24, CMS/HCC V28) No date: Depression No date: DJD (degenerative joint disease) No date: Does mobilize using cane No date: Epilepsy (CMS/HCC V24, CMS/HCC V28) Comment: last seizure: approx June, 2022 pt passed out; was not witnessed per daughter- Dr. Pratik Bhattacharya No date: HL (hearing loss) Comment: wears hearing aids No date: Hyperlipidemia No date: Hypertension Comment: Dr. Patel No date: Incontinence No date: Osteoarthritis No date: Skin cancer Comment: basal cell No date: TIA (transient ischemic attack) Comment: 15
#
# Source: {'id': '117', 'index': 'tiamd_prod_clinical_notes', 'noteId': '117', 'patientName': None, 'dateOfService': None, 'start_index': 800}
# Content: more history and have left a voicemail. Patient has a history of atrial fibrillation (on Eliquis, noncompliant, last dose 3 days ago), cardiomyopathy with an EF of 39% (December 2024, previously 60% in 2021) and grade 2 diastolic dysfunction, CAD by CT calcification, alcohol use disorder, liver cirrhosis, and tobacco use disorder was brought to the ED from his rehab facility (Easter Seals) for unclear reasons. Facility staff reportedly had expressed concern about a possible medical condition. The patient does not routinely see a PCP, is a poor historian, and is frequently nonadherent with medications. His home was described as messy and unsanitary, with evidence of incontinence. He was hospitalized at this facility six months ago for atrial fibrillation, during which cardiology deferred cardioversion due to alcohol withdrawal and recommended outpatient evaluation for possible heart catheterization by Dr. Patel, which the patient likely did not pursue. Social work determined that he
# ================================== Ai Message ==================================
#
# I apologize, but I couldn't find specific information about the total number of patients in the dataset from the context provided. The retrieved information contains details about individual patient records, but it doesn't give us an overview of the entire dataset.
#
# To answer your question accurately, we would need more comprehensive information about the dataset, such as metadata or summary statistics. This kind of information is typically not found in individual clinical notes.
#
# If you have access to any other sources of information about this dataset, such as a data dictionary, dataset description, or summary statistics, that would be helpful in determining the number of patients. Alternatively, if there's a way to query the dataset directly for this information, that would be the most accurate approach.
#
# Is there any other specific information about the dataset that you're looking for, or would you like me to try a different query to find relevant information?

# %%
query = "Number of patients under doctor madhavan?"

for event in agent.stream(
    {"messages": [{"role": "user", "content": query}]},
    stream_mode="values",
):
    event["messages"][-1].pretty_print()
# Out:
# ================================ Human Message =================================
#
# Number of patients under doctor madhavan?
# ================================== Ai Message ==================================
#
# To answer this question, we need to retrieve information about patients under Dr. Madhavan's care. Let's use the retrieve_context function to get this information.
# Tool Calls:
#   retrieve_context (toolu_bdrk_014P7pvY89iTxSjDWriZWw4F)
#  Call ID: toolu_bdrk_014P7pvY89iTxSjDWriZWw4F
#   Args:
#     query: Number of patients under doctor Madhavan
# ================================= Tool Message =================================
# Name: retrieve_context
#
# Source: {'id': '102', 'index': 'tiamd_prod_clinical_notes', 'noteId': '102', 'patientName': None, 'dateOfService': None, 'start_index': 1}
# Content: Barazsu, Frank P MRN:&nbsp;101972538 &nbsp; Ramesh Madhavan, MD Physician Neurology &nbsp; Consults&nbsp;&nbsp;&nbsp; Signed &nbsp; Date of Service:&nbsp;10/5/2025 &nbsp;7:44 AM &nbsp; &nbsp; &nbsp; Signed &nbsp; 43902 Woodward Ave, Suite 100 Bloomfield Twp, MI 48302 Phone #: 248-955-9949 | Fax #: 248-928-2274 Pratik Bhattacharya, MD MPH Taylor Graham, MD Ramesh Madhavan, MD Ismail Rahal DO Alex Tobar, DO &nbsp; Neurology consult &nbsp; Name: Frank P Barazsu DOB: 4/27/1951 Age: 74 y.o. Sex: male MRN: 101972538 CSN: 1000520692912 Admit date: 10/3/2025 Attending: Maan Ekkah, MD Date of consult:10/5/2025 IMC neurology covering for Dr. Basel Assaad &nbsp; Reason for Consult: Altered mental status &nbsp; Subjective &nbsp; HPI 74 y.o. maleis consulted for altered mental staus. He has a with a past medical history significant for coronary artery disease status post PCI, anxiety, congestive heart failure, type 2 diabetes mellitus complicated by diabetic neuropathy and erectile dysfunction,
#
# Source: {'id': '104', 'index': 'tiamd_prod_clinical_notes', 'noteId': '104', 'patientName': None, 'dateOfService': None, 'start_index': 1}
# Content: McHaney, Evelyn MRN:&nbsp;101798833 &nbsp; Ramesh Madhavan, MD Physician Neurology &nbsp; Progress Notes&nbsp;&nbsp;&nbsp; Signed &nbsp; Date of Service:&nbsp;10/5/2025 &nbsp;4:00 PM &nbsp; &nbsp; &nbsp; Signed &nbsp; 43902 Woodward Ave, Suite 100 Bloomfield Twp, MI 48302 Phone #: 248-955-9949 | Fax #: 248-928-2274 Pratik Bhattacharya, MD MPH Taylor Graham, MD Ramesh Madhavan, MD Ismail Rahal DO Alex Tobar, DO &nbsp; Neurology consult &nbsp; Name: Evelyn McHaney DOB: 3/25/1933 Age: 92 y.o. Sex: female MRN: 101798833 CSN: 1000520767156 Admit date: 10/3/2025 Attending: Noura Mansour, MD Date of consult:10/5/2025 CCD: &nbsp; Reason for Consult: Altered mental status and seizure like activity &nbsp; Subjective &nbsp; HPI 92 y.o. female is consulted for Altered mental status and seizure like activity. She has a past medical history of hypertension, tubercular uveitis, cerebrovascular accident (CVA), chronic kidney disease (CKD), glaucoma, and macular degeneration was brought to the
# ================================== Ai Message ==================================
#
# Based on the information retrieved, I can provide some insight about patients under Dr. Madhavan's care, but I cannot give you an exact number of patients. The retrieve_context function has provided information about two patients who are being seen by Dr. Ramesh Madhavan:
#
# 1. Frank P Barazsu (MRN: 101972538)
# 2. Evelyn McHaney (MRN: 101798833)
#
# Both of these patients have notes from consultations or progress notes written by Dr. Ramesh Madhavan. However, it's important to note that this information is limited and may not represent the total number of patients under Dr. Madhavan's care. The function has only returned information about two specific cases, and there could be many more patients not mentioned in these particular notes.
#
# To get an accurate count of all patients under Dr. Madhavan's care, we would need access to a comprehensive patient list or database, which is not available through the current tool. The information provided gives us a glimpse of Dr. Madhavan's practice but does not allow us to determine the total number of his patients.
#
# If you need the exact number of patients under Dr. Madhavan's care, you would need to consult the hospital or clinic's administrative records or patient management system, which would have a complete list of all patients assigned to each doctor.

# %%
query = "Give the soap notes for the patient Frank P Barazsu"

for event in agent.stream(
    {"messages": [{"role": "user", "content": query}]},
    stream_mode="values",
):
    event["messages"][-1].pretty_print()
# Out:
# ================================ Human Message =================================
#
# Give the soap notes for the patient Frank P Barazsu
# ================================== Ai Message ==================================
#
# To provide you with the SOAP notes for the patient Frank P Barazsu, I'll need to retrieve that information from the clinical notes. Let me use the available tool to fetch this data for you.
# Tool Calls:
#   retrieve_context (toolu_bdrk_01K9qTYRKBHwt7T4jbGN643f)
#  Call ID: toolu_bdrk_01K9qTYRKBHwt7T4jbGN643f
#   Args:
#     query: SOAP notes for Frank P Barazsu
# ================================= Tool Message =================================
# Name: retrieve_context
#
# Source: {'id': '102', 'index': 'tiamd_prod_clinical_notes', 'noteId': '102', 'patientName': None, 'dateOfService': None, 'start_index': 1}
# Content: Barazsu, Frank P MRN:&nbsp;101972538 &nbsp; Ramesh Madhavan, MD Physician Neurology &nbsp; Consults&nbsp;&nbsp;&nbsp; Signed &nbsp; Date of Service:&nbsp;10/5/2025 &nbsp;7:44 AM &nbsp; &nbsp; &nbsp; Signed &nbsp; 43902 Woodward Ave, Suite 100 Bloomfield Twp, MI 48302 Phone #: 248-955-9949 | Fax #: 248-928-2274 Pratik Bhattacharya, MD MPH Taylor Graham, MD Ramesh Madhavan, MD Ismail Rahal DO Alex Tobar, DO &nbsp; Neurology consult &nbsp; Name: Frank P Barazsu DOB: 4/27/1951 Age: 74 y.o. Sex: male MRN: 101972538 CSN: 1000520692912 Admit date: 10/3/2025 Attending: Maan Ekkah, MD Date of consult:10/5/2025 IMC neurology covering for Dr. Basel Assaad &nbsp; Reason for Consult: Altered mental status &nbsp; Subjective &nbsp; HPI 74 y.o. maleis consulted for altered mental staus. He has a with a past medical history significant for coronary artery disease status post PCI, anxiety, congestive heart failure, type 2 diabetes mellitus complicated by diabetic neuropathy and erectile dysfunction,
#
# Source: {'id': '125', 'index': 'tiamd_prod_clinical_notes', 'noteId': '125', 'patientName': None, 'dateOfService': None, 'start_index': 805}
# Content: the care of a neurologist since 2020. He previously worked as an environmental manager(chemical engineer in UofM), monitoring pollution and ventilation in production plants, and retired in 2009. He stated that he had no neurological issues until 2020. During a hospitalization for atrial fibrillation and pulmonary disease, he was also noted to have foot drop, which later resolved. He reported having fine tremors in his hands for years, which began worsening in 2020 and continued to progress. He had been following with Dr. Fadi H. Delly, MD, since then. &nbsp; He described tremors as fine, resting, flexion-extension tremors in both hands. He also endorsed low-amplitude supination-pronation tremors at the elbows, particularly when holding or moving objects. He noted difficulty eating certain foods like soup and peas, although he was able to drink coffee by filling the cup only halfway to avoid spilling. He also reported ongoing balance issues that began in 2020. He experienced two falls
# ================================== Ai Message ==================================
#
# Based on the retrieved information, I can provide you with a summary of the SOAP notes for Frank P Barazsu. However, it's important to note that the retrieved information doesn't follow the traditional SOAP (Subjective, Objective, Assessment, Plan) format exactly. Instead, it appears to be a neurology consult note. I'll organize the available information in a SOAP-like structure:
#
# S (Subjective):
# - Patient: Frank P Barazsu
# - DOB: 4/27/1951
# - Age: 74 years old
# - Sex: Male
# - MRN: 101972538
# - CSN: 1000520692912
# - Admit date: 10/3/2025
# - Date of consult: 10/5/2025
# - Reason for Consult: Altered mental status
#
# History:
# - Past medical history significant for:
#   - Coronary artery disease status post PCI
#   - Anxiety
#   - Congestive heart failure
#   - Type 2 diabetes mellitus complicated by diabetic neuropathy
#   - Erectile dysfunction
# - Under neurologist care since 2020
# - Previously worked as an environmental manager (chemical engineer at UofM), retired in 2009
# - No neurological issues until 2020
# - During a hospitalization for atrial fibrillation and pulmonary disease, noted to have foot drop (later resolved)
# - Fine tremors in hands for years, worsening since 2020
# - Following with Dr. Fadi H. Delly, MD since 2020
#
# Current Symptoms:
# - Fine, resting, flexion-extension tremors in both hands
# - Low-amplitude supination-pronation tremors at the elbows, particularly when holding or moving objects
# - Difficulty eating certain foods like soup and peas
# - Able to drink coffee by filling the cup only halfway to avoid spilling
# - Ongoing balance issues since 2020
# - Experienced two falls (details not provided in the excerpt)
#
# O (Objective):
# The retrieved information does not provide specific objective findings from the physical examination.
#
# A (Assessment):
# The note doesn't explicitly state a diagnosis, but the patient's symptoms suggest a possible movement disorder, potentially Parkinson's disease or essential tremor, given the progressive tremors and balance issues.
#
# P (Plan):
# The plan is not explicitly stated in the retrieved information. However, given that this is a neurology consult, it's likely that further neurological evaluation and management will be recommended.
#
# It's important to note that this information is from a neurology consult dated 10/5/2025, which appears to be a future date. This could be a typographical error in the medical record. The attending physician is listed as Maan Ekkah, MD, with the neurology consult being performed by the IMC neurology team covering for Dr. Basel Assaad.
#
# For a more comprehensive and up-to-date SOAP note, you may need to consult the most recent medical records or speak directly with the patient's current healthcare provider.
